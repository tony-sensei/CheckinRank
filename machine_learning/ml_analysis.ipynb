# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
pd.set_option("display.precision", 4)

# %%
# reading dataframe
df = pd.read_csv("/Users/joanna/Downloads/STAT 170B/CheckinRank/machine_learning/data/statistical.csv")
df.head(10)
# Out:
#    longitude  latitude  zipcode  population  day  time  checkinNum
# 0   -82.7333   28.2173    34652       72441    1   3.0         0.0  \
# 1   -82.7333   28.2173    34652       72441    1   8.5         0.0
# 2   -82.7333   28.2173    34652       72441    1  12.0         0.0
# 3   -82.7333   28.2173    34652       72441    1  15.5         0.0
# 4   -82.7333   28.2173    34652       72441    1  19.0         0.0
# 5   -82.7333   28.2173    34652       72441    1  22.0         0.0
# 6   -82.7333   28.2173    34652       72441    2   3.0         0.0
# 7   -82.7333   28.2173    34652       72441    2   8.5         0.0
# 8   -82.7333   28.2173    34652       72441    2  12.0         0.0
# 9   -82.7333   28.2173    34652       72441    2  15.5         0.0
#
#    review_count  restaurant_count  income
# 0            24                90   69551
# 1            24                90   69551
# 2            24                90   69551
# 3            24                90   69551
# 4            24                90   69551
# 5            24                90   69551
# 6            24                90   69551
# 7            24                90   69551
# 8            24                90   69551
# 9            24                90   69551

# %%
new_df = df.drop(["longitude", "latitude", "zipcode", "day", "time"], axis=1)
new_df.head(10)
# Out:
#    population  checkinNum  review_count  restaurant_count  income
# 0       72441         0.0            24                90   69551
# 1       72441         0.0            24                90   69551
# 2       72441         0.0            24                90   69551
# 3       72441         0.0            24                90   69551
# 4       72441         0.0            24                90   69551
# 5       72441         0.0            24                90   69551
# 6       72441         0.0            24                90   69551
# 7       72441         0.0            24                90   69551
# 8       72441         0.0            24                90   69551
# 9       72441         0.0            24                90   69551

# %%
# Calculate the correlation matrix
corr_matrix = new_df.corr()

# Plot the correlation matrix as a heatmap
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Plot')
plt.show()

# %%
# reading dataframe
df = pd.read_csv("/Users/joanna/Downloads/STAT 170B/CheckinRank/machine_learning/data/top_100_tokens.csv")
df.head(10)
# Out:
#         token  count
# 0        food   1997
# 1         ##s   1450
# 2       great   1162
# 3        good   1100
# 4      indian    908
# 5       place    901
# 6     service    855
# 7         ##y    748
# 8  restaurant    712
# 9        like    679

# %%
tokensDict = {}

for index, row in df.iterrows():
    token = row["token"]
    count = row["count"]
    if token.startswith("#") == False and token not in ["ta", "cha", "one", "also", "would", "us", "ind", "na", "5"]:
        tokensDict[token] = count
    if len(tokensDict) == 30:
        break 

print(tokensDict, '\n')
print([i for i in tokensDict.keys()])
# Out:
# {'food': 1997, 'great': 1162, 'good': 1100, 'indian': 908, 'place': 901, 'service': 855, 'restaurant': 712, 'like': 679, 'menu': 665, 'chicken': 655, 'delicious': 624, 'time': 594, 'back': 586, 'really': 562, 'ordered': 535, 'go': 502, 'get': 489, 'came': 468, 'well': 448, 'happy': 441, 'nice': 439, 'order': 413, 'try': 412, 'definitely': 411, 'got': 410, 'spin': 409, 'amazing': 408, 'bar': 406, 'best': 383, 'hour': 377}
#
# ['food', 'great', 'good', 'indian', 'place', 'service', 'restaurant', 'like', 'menu', 'chicken', 'delicious', 'time', 'back', 'really', 'ordered', 'go', 'get', 'came', 'well', 'happy', 'nice', 'order', 'try', 'definitely', 'got', 'spin', 'amazing', 'bar', 'best', 'hour']

# %%
from wordcloud import WordCloud

# create a WordCloud object
wordcloud = WordCloud(width=800, height=800, background_color="white").generate_from_frequencies(tokensDict)

# display the generated wordcloud using matplotlib
plt.figure()
plt.imshow(wordcloud)
plt.axis("off")
plt.show()
